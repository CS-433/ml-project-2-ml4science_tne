# %% [markdown]
# # Analysis of the impact of channels on the Action Recognition task

# %% [markdown]
# In this notebook, we analyze the impact on accuracy of the number of channels used for training the models. We add channels by ascending order of their p-value on the responsive t-test.

# %% [markdown]
# ### Import librairies

# %%
from utils import *
from dataset import *
from constants import *
from models.BaseModels import *

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from dataset import Participant

# Reproducibility
seed_num = RANDOM_STATE # This seed will be used for all random number generators
random.seed(seed_num) # Python's random will use seed_num
np.random.seed(seed_num) # NumPy's random number generator will use seed_num

# %% [markdown]
# ### Data loading

# %% [markdown]
# Change here the participant to load.

# %%
use_saved = True
part_name = 's6'

# %%
if use_saved and os.path.exists(f'saved/{part_name}.pkl'):
    participant = Participant.load_from_pickle(f'saved/{part_name}.pkl')
else:
    participant = Participant(part_name, data_path=DATA_PATH_NOTEBOOK, alpha=ALPHA)
    saved_dir = os.path.join(os.getcwd(), 'saved')
    if not os.path.exists(saved_dir):
        os.makedirs(saved_dir)
    with open(f'saved/{part_name}.pkl', 'wb') as f:
        pickle.dump(participant, f, pickle.HIGHEST_PROTOCOL)

# %%
test_size = 0.3
pca_expl_var = 0.95

# %% [markdown]
# <span style='color: red'>WARNING</span>: computing all features takes up to 26 minutes for (participant s12) (Intel Core i7-7700K)

# %%
features_dict = {}

for channel_idx in range(len(participant.relevant_channels_both)):
    features_dict[channel_idx] = participant.get_features_all_sessions_ExObs(channels=[channel_idx])
# Out:
# 100%|██████████| 256/256 [00:09<00:00, 26.23it/s]
# 100%|██████████| 256/256 [00:08<00:00, 29.41it/s]
# 100%|██████████| 256/256 [00:08<00:00, 28.97it/s]
# 100%|██████████| 256/256 [00:08<00:00, 28.72it/s]
# 100%|██████████| 256/256 [00:09<00:00, 28.38it/s]
# 100%|██████████| 256/256 [00:08<00:00, 29.30it/s]
# 100%|██████████| 256/256 [00:08<00:00, 29.24it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.41it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.61it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.70it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.65it/s]
# 100%|██████████| 256/256 [00:10<00:00, 23.79it/s]
# 100%|██████████| 256/256 [00:09<00:00, 25.64it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.87it/s]
# 100%|██████████| 256/256 [00:09<00:00, 25.67it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.51it/s]
# 100%|██████████| 256/256 [00:10<00:00, 23.94it/s]
# 100%|██████████| 256/256 [00:10<00:00, 23.61it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.73it/s]
# 100%|██████████| 256/256 [00:10<00:00, 25.15it/s]
# 100%|██████████| 256/256 [00:10<00:00, 25.00it/s]
# 100%|██████████| 256/256 [00:10<00:00, 25.51it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.10it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.83it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.86it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.08it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.49it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.10it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.89it/s]
# 100%|██████████| 256/256 [00:10<00:00, 23.48it/s]
# 100%|██████████| 256/256 [00:11<00:00, 23.25it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.45it/s]
# 100%|██████████| 256/256 [00:11<00:00, 23.13it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.65it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.73it/s]
# 100%|██████████| 256/256 [00:09<00:00, 27.08it/s]
# 100%|██████████| 256/256 [00:10<00:00, 25.56it/s]
# 100%|██████████| 256/256 [00:09<00:00, 27.26it/s]
# 100%|██████████| 256/256 [00:09<00:00, 27.11it/s]
# 100%|██████████| 256/256 [00:10<00:00, 24.75it/s]

# %% [markdown]
# ### Run models

# %%
logreg_accuracies = []
logreg_pca_accuracies = []
svm_accuracies = []
svm_pca_accuracies = []
rf_accuracies = []

y = features_dict[0]['label']
for top_channels in range(1, len(participant.relevant_channels_both)+1):
    features = pd.concat([features_dict[i].drop('label', axis=1) for i in range(top_channels)], axis=1)
    print(f'The dataset contains {features.shape[0]} samples and {features.shape[1]} features.')
    print(f'The {len(participant.relevant_channels_both[:top_channels])} most relevant channels are located in the following locations:')
    regions = [participant.channels_locations[i] for i in [channel.idx for channel in participant.relevant_channels_both[:top_channels]]]
    channels_per_regions = {}
    for region in set(regions):
        channels_per_regions[region] = regions.count(region)
    print(channels_per_regions)

    X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=test_size, random_state=RANDOM_STATE)
    logreg = LogisticRegressionModel()
    logreg.fit(X_train, y_train)
    y_pred = logreg.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    logreg_accuracies.append(accuracy)
    print(f"LogReg Accuracy: {accuracy:.2f}")
    logreg = LogisticRegressionModel(use_pca=True, expl_var=pca_expl_var)
    logreg.fit(X_train, y_train)
    y_pred = logreg.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    logreg_pca_accuracies.append(accuracy)
    print(f"LogReg PCA Accuracy: {accuracy:.2f}")
    svm = SVMModel()
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    svm_accuracies.append(accuracy)
    print(f"SVM Accuracy: {accuracy:.2f}")
    svm = SVMModel(use_pca=True, expl_var=pca_expl_var)
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    svm_pca_accuracies.append(accuracy)
    print(f"SVM PCA Accuracy: {accuracy:.2f}")
    svm = RandomForestModel()
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    rf_accuracies.append(accuracy)
    print(f"RF Accuracy: {accuracy:.2f}")
# Out:
# The dataset contains 256 samples and 72 features.
# The 1 most relevant channels are located in the following locations:
# {'postcentral': 1}
# LogReg Accuracy: 0.70
# LogReg PCA Accuracy: 0.68
# SVM Accuracy: 0.70
# SVM PCA Accuracy: 0.68
# RF Accuracy: 0.68
# The dataset contains 256 samples and 144 features.
# The 2 most relevant channels are located in the following locations:
# {'precentral': 1, 'postcentral': 1}
# LogReg Accuracy: 0.82
# LogReg PCA Accuracy: 0.88
# SVM Accuracy: 0.86
# SVM PCA Accuracy: 0.83
# RF Accuracy: 0.77
# The dataset contains 256 samples and 216 features.
# The 3 most relevant channels are located in the following locations:
# {'precentral': 2, 'postcentral': 1}
# LogReg Accuracy: 0.79
# LogReg PCA Accuracy: 0.78
# SVM Accuracy: 0.78
# SVM PCA Accuracy: 0.77
# RF Accuracy: 0.81
# The dataset contains 256 samples and 288 features.
# The 4 most relevant channels are located in the following locations:
# {'precentral': 3, 'postcentral': 1}
# LogReg Accuracy: 0.82
# LogReg PCA Accuracy: 0.79
# SVM Accuracy: 0.78
# SVM PCA Accuracy: 0.79
# RF Accuracy: 0.82
# The dataset contains 256 samples and 360 features.
# The 5 most relevant channels are located in the following locations:
# {'precentral': 3, 'postcentral': 2}
# LogReg Accuracy: 0.83
# LogReg PCA Accuracy: 0.82
# SVM Accuracy: 0.82
# SVM PCA Accuracy: 0.86
# RF Accuracy: 0.82
# The dataset contains 256 samples and 432 features.
# The 6 most relevant channels are located in the following locations:
# {'precentral': 4, 'postcentral': 2}
# LogReg Accuracy: 0.87
# LogReg PCA Accuracy: 0.83
# SVM Accuracy: 0.83
# SVM PCA Accuracy: 0.83
# RF Accuracy: 0.82
# The dataset contains 256 samples and 504 features.
# The 7 most relevant channels are located in the following locations:
# {'precentral': 4, 'postcentral': 3}
# LogReg Accuracy: 0.91
# LogReg PCA Accuracy: 0.88
# SVM Accuracy: 0.92
# SVM PCA Accuracy: 0.87
# RF Accuracy: 0.86
# The dataset contains 256 samples and 576 features.
# The 8 most relevant channels are located in the following locations:
# {'precentral': 4, 'postcentral': 4}
# LogReg Accuracy: 0.95
# LogReg PCA Accuracy: 0.94
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.90
# RF Accuracy: 0.86
# The dataset contains 256 samples and 648 features.
# The 9 most relevant channels are located in the following locations:
# {'precentral': 4, 'postcentral': 5}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.95
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.87
# The dataset contains 256 samples and 720 features.
# The 10 most relevant channels are located in the following locations:
# {'precentral': 5, 'postcentral': 5}
# LogReg Accuracy: 0.94
# LogReg PCA Accuracy: 0.92
# SVM Accuracy: 0.92
# SVM PCA Accuracy: 0.92
# RF Accuracy: 0.84
# The dataset contains 256 samples and 792 features.
# The 11 most relevant channels are located in the following locations:
# {'precentral': 5, 'postcentral': 5, 'caudalmiddlefrontal': 1}
# LogReg Accuracy: 0.95
# LogReg PCA Accuracy: 0.92
# SVM Accuracy: 0.94
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.84
# The dataset contains 256 samples and 864 features.
# The 12 most relevant channels are located in the following locations:
# {'precentral': 5, 'postcentral': 5, 'superiorfrontal': 1, 'caudalmiddlefrontal': 1}
# LogReg Accuracy: 0.94
# LogReg PCA Accuracy: 0.92
# SVM Accuracy: 0.91
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.86
# The dataset contains 256 samples and 936 features.
# The 13 most relevant channels are located in the following locations:
# {'postcentral': 5, 'WM_precentral': 1, 'caudalmiddlefrontal': 1, 'precentral': 5, 'superiorfrontal': 1}
# LogReg Accuracy: 0.91
# LogReg PCA Accuracy: 0.88
# SVM Accuracy: 0.90
# SVM PCA Accuracy: 0.88
# RF Accuracy: 0.90
# The dataset contains 256 samples and 1008 features.
# The 14 most relevant channels are located in the following locations:
# {'postcentral': 6, 'WM_precentral': 1, 'caudalmiddlefrontal': 1, 'precentral': 5, 'superiorfrontal': 1}
# LogReg Accuracy: 0.91
# LogReg PCA Accuracy: 0.88
# SVM Accuracy: 0.94
# SVM PCA Accuracy: 0.91
# RF Accuracy: 0.87
# The dataset contains 256 samples and 1080 features.
# The 15 most relevant channels are located in the following locations:
# {'postcentral': 6, 'WM_precentral': 1, 'caudalmiddlefrontal': 1, 'precentral': 6, 'superiorfrontal': 1}
# LogReg Accuracy: 0.94
# LogReg PCA Accuracy: 0.92
# SVM Accuracy: 0.94
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.88
# The dataset contains 256 samples and 1152 features.
# The 16 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 1, 'caudalmiddlefrontal': 1, 'precentral': 6, 'superiorfrontal': 1}
# LogReg Accuracy: 0.91
# LogReg PCA Accuracy: 0.90
# SVM Accuracy: 0.91
# SVM PCA Accuracy: 0.91
# RF Accuracy: 0.88
# The dataset contains 256 samples and 1224 features.
# The 17 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 2, 'caudalmiddlefrontal': 1, 'precentral': 6, 'superiorfrontal': 1}
# LogReg Accuracy: 0.91
# LogReg PCA Accuracy: 0.92
# SVM Accuracy: 0.91
# SVM PCA Accuracy: 0.95
# RF Accuracy: 0.90
# The dataset contains 256 samples and 1296 features.
# The 18 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 3, 'caudalmiddlefrontal': 1, 'precentral': 6, 'superiorfrontal': 1}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.96
# SVM Accuracy: 0.96
# SVM PCA Accuracy: 0.95
# RF Accuracy: 0.92
# The dataset contains 256 samples and 1368 features.
# The 19 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 3, 'caudalmiddlefrontal': 2, 'precentral': 6, 'superiorfrontal': 1}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.96
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.95
# The dataset contains 256 samples and 1440 features.
# The 20 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 2, 'precentral': 6, 'superiorfrontal': 1}
# LogReg Accuracy: 0.97
# LogReg PCA Accuracy: 0.96
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.95
# RF Accuracy: 0.96
# The dataset contains 256 samples and 1512 features.
# The 21 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 2, 'precentral': 6, 'superiorfrontal': 2}
# LogReg Accuracy: 0.95
# LogReg PCA Accuracy: 0.95
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.95
# RF Accuracy: 0.95
# The dataset contains 256 samples and 1584 features.
# The 22 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 6, 'superiorfrontal': 2}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.95
# SVM Accuracy: 0.94
# SVM PCA Accuracy: 0.96
# RF Accuracy: 0.94
# The dataset contains 256 samples and 1656 features.
# The 23 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 7, 'superiorfrontal': 2}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.95
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.96
# The dataset contains 256 samples and 1728 features.
# The 24 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 8, 'superiorfrontal': 2}
# LogReg Accuracy: 0.97
# LogReg PCA Accuracy: 0.95
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.92
# The dataset contains 256 samples and 1800 features.
# The 25 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 9, 'superiorfrontal': 2}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.96
# SVM Accuracy: 0.97
# SVM PCA Accuracy: 0.95
# RF Accuracy: 0.96
# The dataset contains 256 samples and 1872 features.
# The 26 most relevant channels are located in the following locations:
# {'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 10, 'superiorfrontal': 2}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.96
# SVM Accuracy: 0.96
# SVM PCA Accuracy: 0.95
# RF Accuracy: 0.96
# The dataset contains 256 samples and 1944 features.
# The 27 most relevant channels are located in the following locations:
# {'insula': 1, 'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 10, 'superiorfrontal': 2}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.95
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.95
# RF Accuracy: 0.96
# The dataset contains 256 samples and 2016 features.
# The 28 most relevant channels are located in the following locations:
# {'insula': 1, 'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 10, 'superiorfrontal': 3}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.96
# SVM Accuracy: 0.94
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.96
# The dataset contains 256 samples and 2088 features.
# The 29 most relevant channels are located in the following locations:
# {'insula': 2, 'postcentral': 7, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 10, 'superiorfrontal': 3}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.96
# SVM Accuracy: 0.94
# SVM PCA Accuracy: 0.95
# RF Accuracy: 0.96
# The dataset contains 256 samples and 2160 features.
# The 30 most relevant channels are located in the following locations:
# {'insula': 2, 'postcentral': 8, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 10, 'superiorfrontal': 3}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.96
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.96
# The dataset contains 256 samples and 2232 features.
# The 31 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 8, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 10, 'superiorfrontal': 3}
# LogReg Accuracy: 0.96
# LogReg PCA Accuracy: 0.96
# SVM Accuracy: 0.95
# SVM PCA Accuracy: 0.94
# RF Accuracy: 0.96
# The dataset contains 256 samples and 2304 features.
# The 32 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 8, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 11, 'superiorfrontal': 3}
# LogReg Accuracy: 0.99
# LogReg PCA Accuracy: 0.99
# SVM Accuracy: 0.97
# SVM PCA Accuracy: 0.97
# RF Accuracy: 0.99
# The dataset contains 256 samples and 2376 features.
# The 33 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 8, 'WM_precentral': 4, 'caudalmiddlefrontal': 3, 'precentral': 12, 'superiorfrontal': 3}
# LogReg Accuracy: 1.00
# LogReg PCA Accuracy: 0.99
# SVM Accuracy: 0.99
# SVM PCA Accuracy: 1.00
# RF Accuracy: 0.97
# The dataset contains 256 samples and 2448 features.
# The 34 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 8, 'WM_precentral': 4, 'caudalmiddlefrontal': 4, 'precentral': 12, 'superiorfrontal': 3}
# LogReg Accuracy: 1.00
# LogReg PCA Accuracy: 0.99
# SVM Accuracy: 1.00
# SVM PCA Accuracy: 1.00
# RF Accuracy: 0.97
# The dataset contains 256 samples and 2520 features.
# The 35 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 8, 'WM_precentral': 4, 'caudalmiddlefrontal': 4, 'precentral': 13, 'superiorfrontal': 3}
# LogReg Accuracy: 1.00
# LogReg PCA Accuracy: 1.00
# SVM Accuracy: 1.00
# SVM PCA Accuracy: 1.00
# RF Accuracy: 0.99
# The dataset contains 256 samples and 2592 features.
# The 36 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 8, 'paracentral': 1, 'WM_precentral': 4, 'caudalmiddlefrontal': 4, 'precentral': 13, 'superiorfrontal': 3}
# LogReg Accuracy: 0.99
# LogReg PCA Accuracy: 0.99
# SVM Accuracy: 0.99
# SVM PCA Accuracy: 0.99
# RF Accuracy: 0.99
# The dataset contains 256 samples and 2664 features.
# The 37 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 8, 'paracentral': 1, 'WM_precentral': 4, 'caudalmiddlefrontal': 4, 'precentral': 13, 'superiorfrontal': 4}
# LogReg Accuracy: 0.99
# LogReg PCA Accuracy: 1.00
# SVM Accuracy: 1.00
# SVM PCA Accuracy: 0.99
# RF Accuracy: 1.00
# The dataset contains 256 samples and 2736 features.
# The 38 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 8, 'paracentral': 1, 'WM_precentral': 4, 'caudalmiddlefrontal': 4, 'precentral': 13, 'superiorfrontal': 5}
# LogReg Accuracy: 1.00
# LogReg PCA Accuracy: 1.00
# SVM Accuracy: 1.00
# SVM PCA Accuracy: 0.99
# RF Accuracy: 1.00
# The dataset contains 256 samples and 2808 features.
# The 39 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 9, 'paracentral': 1, 'WM_precentral': 4, 'caudalmiddlefrontal': 4, 'precentral': 13, 'superiorfrontal': 5}
# LogReg Accuracy: 0.99
# LogReg PCA Accuracy: 0.99
# SVM Accuracy: 0.99
# SVM PCA Accuracy: 0.99
# RF Accuracy: 0.99
# The dataset contains 256 samples and 2880 features.
# The 40 most relevant channels are located in the following locations:
# {'insula': 3, 'postcentral': 9, 'paracentral': 1, 'WM_precentral': 5, 'caudalmiddlefrontal': 4, 'precentral': 13, 'superiorfrontal': 5}
# LogReg Accuracy: 0.99
# LogReg PCA Accuracy: 1.00
# SVM Accuracy: 0.99
# SVM PCA Accuracy: 0.99
# RF Accuracy: 0.99

# %%
# General
plt.rcParams["font.family"] = "Times New Roman"
SMALL_SIZE = 18
MEDIUM_SIZE = 20
BIGGER_SIZE = 22

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE, titleweight = 'bold', titlepad = 20)    # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE, labelweight = 'bold', labelpad = 15)   # fontsize of the x and y labels    
plt.rc('xtick', labelsize=SMALL_SIZE, direction = 'out')    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE, direction = 'out')    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('axes.spines', top=False, right=False)  # Removing the top and right spines   

plt.plot(logreg_accuracies, '--', alpha=0.7, label='Logistic Regression')
plt.plot(logreg_pca_accuracies, '--', alpha=0.7, label='Logistic Regression PCA')
plt.plot(svm_accuracies, '--', alpha=0.7, label='SVM')
plt.plot(svm_pca_accuracies, '--', alpha=0.7, label='SVM PCA')
plt.plot(rf_accuracies, '--', alpha=0.7, label='Random Forest')
plt.legend(fontsize=15)
plt.xlabel('Number of most relevant channels')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. number of most relevant channels')
plt.savefig(f'figures/{part_name}_acc_vs_channels.png', bbox_inches='tight')
plt.show()
