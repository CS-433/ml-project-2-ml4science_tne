# %%
from utils import *
from dataset import *
from constants import *
from models.BaseModels import *

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from dataset import Participant

random.seed(RANDOM_STATE)

# %%
use_saved = True
part_name = 's6'

# %%
if use_saved and os.path.exists(f'saved/{part_name}.pkl'):
    participant = Participant.load_from_pickle(f'saved/{part_name}.pkl')
else:
    participant = Participant(part_name, data_path=DATA_PATH_NOTEBOOK, alpha=ALPHA)
    saved_dir = os.path.join(os.getcwd(), 'saved')
    if not os.path.exists(saved_dir):
        os.makedirs(saved_dir)
    with open(f'saved/{part_name}.pkl', 'wb') as f:
        pickle.dump(participant, f, pickle.HIGHEST_PROTOCOL)

# %%
test_size = 0.3
pca_expl_var = 0.95

# %% [markdown]
# ## Observation

# %%
obs_features_dict = {}

for channel_idx in range(len(participant.relevant_channels_obs)):
    obs_features_dict[channel_idx] = participant.get_features_all_sessions_mvt('O', channels=[channel_idx])
# Out:
# 100%|██████████| 256/256 [00:07<00:00, 36.33it/s]
# 100%|██████████| 256/256 [00:06<00:00, 37.27it/s]
# 100%|██████████| 256/256 [00:06<00:00, 36.68it/s]
# 100%|██████████| 256/256 [00:07<00:00, 36.53it/s]
# 100%|██████████| 256/256 [00:07<00:00, 34.40it/s]
# 100%|██████████| 256/256 [00:06<00:00, 36.73it/s]
# 100%|██████████| 256/256 [00:07<00:00, 35.21it/s]
# 100%|██████████| 256/256 [00:07<00:00, 34.84it/s]
# 100%|██████████| 256/256 [00:06<00:00, 37.14it/s]
# 100%|██████████| 256/256 [00:06<00:00, 37.17it/s]
# 100%|██████████| 256/256 [00:06<00:00, 36.64it/s]
# 100%|██████████| 256/256 [00:06<00:00, 36.76it/s]
# 100%|██████████| 256/256 [00:07<00:00, 35.73it/s]
# 100%|██████████| 256/256 [00:06<00:00, 36.79it/s]
# 100%|██████████| 256/256 [00:07<00:00, 36.40it/s]
# 100%|██████████| 256/256 [00:09<00:00, 27.03it/s]
# 100%|██████████| 256/256 [00:08<00:00, 29.37it/s]
# 100%|██████████| 256/256 [00:08<00:00, 29.78it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.85it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.57it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.29it/s]
# 100%|██████████| 256/256 [00:08<00:00, 31.89it/s]
# 100%|██████████| 256/256 [00:07<00:00, 33.05it/s]
# 100%|██████████| 256/256 [00:08<00:00, 30.95it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.76it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.37it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.08it/s]
# 100%|██████████| 256/256 [00:08<00:00, 31.67it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.57it/s]
# 100%|██████████| 256/256 [00:08<00:00, 31.39it/s]
# 100%|██████████| 256/256 [00:08<00:00, 31.80it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.28it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.69it/s]
# 100%|██████████| 256/256 [00:08<00:00, 31.40it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.67it/s]
# 100%|██████████| 256/256 [00:08<00:00, 31.49it/s]
# 100%|██████████| 256/256 [00:08<00:00, 29.73it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.15it/s]
# 100%|██████████| 256/256 [00:08<00:00, 29.31it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.12it/s]
# 100%|██████████| 256/256 [00:08<00:00, 28.93it/s]
# 100%|██████████| 256/256 [00:08<00:00, 29.34it/s]
# 100%|██████████| 256/256 [00:08<00:00, 31.60it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.53it/s]
# 100%|██████████| 256/256 [00:08<00:00, 31.79it/s]
# 100%|██████████| 256/256 [00:07<00:00, 32.04it/s]
# 100%|██████████| 256/256 [00:08<00:00, 31.41it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.28it/s]
# 100%|██████████| 256/256 [00:09<00:00, 26.28it/s]
# 100%|██████████| 256/256 [00:08<00:00, 28.65it/s]
# 100%|██████████| 256/256 [00:08<00:00, 28.96it/s]

# %%
logreg_accuracies = []
logreg_pca_accuracies = []
svm_accuracies = []
svm_pca_accuracies = []
rf_accuracies = []

y = obs_features_dict[0]['label']
for top_channels in range(1, len(participant.relevant_channels_obs)+1):
    obs_features = pd.concat([obs_features_dict[i].drop('label', axis=1) for i in range(top_channels)], axis=1)
    print(f'The dataset contains {obs_features.shape[0]} samples and {obs_features.shape[1]} features.')
    print(f'The {len(participant.relevant_channels_obs[:top_channels])} most relevant channels are located in the following locations:')
    regions = [participant.channels_locations[i] for i in [channel.idx for channel in participant.relevant_channels_obs[:top_channels]]]
    channels_per_regions = {}
    for region in set(regions):
        channels_per_regions[region] = regions.count(region)
    print(channels_per_regions)

    X_train, X_test, y_train, y_test = train_test_split(obs_features, y, test_size=test_size, random_state=RANDOM_STATE)
    logreg = LogisticRegressionModel()
    logreg.fit(X_train, y_train)
    y_pred = logreg.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    logreg_accuracies.append(accuracy)
    print(f"LogReg Accuracy: {accuracy:.2f}")
    logreg = LogisticRegressionModel(use_pca=True, expl_var=pca_expl_var)
    logreg.fit(X_train, y_train)
    y_pred = logreg.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    logreg_pca_accuracies.append(accuracy)
    print(f"LogReg PCA Accuracy: {accuracy:.2f}")
    svm = SVMModel()
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    svm_accuracies.append(accuracy)
    print(f"SVM Accuracy: {accuracy:.2f}")
    svm = SVMModel(use_pca=True, expl_var=pca_expl_var)
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    svm_pca_accuracies.append(accuracy)
    print(f"SVM PCA Accuracy: {accuracy:.2f}")
    svm = RandomForestModel()
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    rf_accuracies.append(accuracy)
    print(f"RF Accuracy: {accuracy:.2f}")
# Out:
# The dataset contains 128 samples and 72 features.
# The 1 most relevant channels are located in the following locations:
# {'postcentral': 1}
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.56
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.51
# The dataset contains 128 samples and 144 features.
# The 2 most relevant channels are located in the following locations:
# {'postcentral': 2}
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.64
# SVM Accuracy: 0.49
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.64
# The dataset contains 128 samples and 216 features.
# The 3 most relevant channels are located in the following locations:
# {'postcentral': 3}
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.62
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.54
# The dataset contains 128 samples and 288 features.
# The 4 most relevant channels are located in the following locations:
# {'postcentral': 3, 'precentral': 1}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.59
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.54
# The dataset contains 128 samples and 360 features.
# The 5 most relevant channels are located in the following locations:
# {'postcentral': 4, 'precentral': 1}
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.44
# The dataset contains 128 samples and 432 features.
# The 6 most relevant channels are located in the following locations:
# {'postcentral': 4, 'precentral': 2}
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.49
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.44
# The dataset contains 128 samples and 504 features.
# The 7 most relevant channels are located in the following locations:
# {'postcentral': 4, 'precentral': 3}
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.62
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.54
# The dataset contains 128 samples and 576 features.
# The 8 most relevant channels are located in the following locations:
# {'postcentral': 4, 'precentral': 4}
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.38
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.49
# The dataset contains 128 samples and 648 features.
# The 9 most relevant channels are located in the following locations:
# {'postcentral': 5, 'precentral': 4}
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.51
# The dataset contains 128 samples and 720 features.
# The 10 most relevant channels are located in the following locations:
# {'postcentral': 6, 'precentral': 4}
# LogReg Accuracy: 0.46
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.54
# The dataset contains 128 samples and 792 features.
# The 11 most relevant channels are located in the following locations:
# {'postcentral': 6, 'precentral': 5}
# LogReg Accuracy: 0.44
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.44
# The dataset contains 128 samples and 864 features.
# The 12 most relevant channels are located in the following locations:
# {'postcentral': 7, 'precentral': 5}
# LogReg Accuracy: 0.44
# LogReg PCA Accuracy: 0.59
# SVM Accuracy: 0.41
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.44
# The dataset contains 128 samples and 936 features.
# The 13 most relevant channels are located in the following locations:
# {'superiorfrontal': 1, 'postcentral': 7, 'precentral': 5}
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.51
# The dataset contains 128 samples and 1008 features.
# The 14 most relevant channels are located in the following locations:
# {'superiorfrontal': 2, 'postcentral': 7, 'precentral': 5}
# LogReg Accuracy: 0.41
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.41
# The dataset contains 128 samples and 1080 features.
# The 15 most relevant channels are located in the following locations:
# {'superiorfrontal': 3, 'postcentral': 7, 'precentral': 5}
# LogReg Accuracy: 0.44
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.46
# The dataset contains 128 samples and 1152 features.
# The 16 most relevant channels are located in the following locations:
# {'superiorfrontal': 3, 'postcentral': 7, 'precentral': 5, 'WM_precentral': 1}
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.49
# The dataset contains 128 samples and 1224 features.
# The 17 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 1, 'WM_precentral': 1, 'superiorfrontal': 3, 'postcentral': 7, 'precentral': 5}
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.59
# The dataset contains 128 samples and 1296 features.
# The 18 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 2, 'WM_precentral': 1, 'superiorfrontal': 3, 'postcentral': 7, 'precentral': 5}
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.51
# The dataset contains 128 samples and 1368 features.
# The 19 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 2, 'WM_precentral': 1, 'superiorfrontal': 4, 'postcentral': 7, 'precentral': 5}
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.56
# The dataset contains 128 samples and 1440 features.
# The 20 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 3, 'WM_precentral': 1, 'superiorfrontal': 4, 'postcentral': 7, 'precentral': 5}
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.56
# The dataset contains 128 samples and 1512 features.
# The 21 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 3, 'WM_precentral': 1, 'superiorfrontal': 4, 'postcentral': 7, 'precentral': 6}
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.44
# The dataset contains 128 samples and 1584 features.
# The 22 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 3, 'WM_precentral': 2, 'superiorfrontal': 4, 'postcentral': 7, 'precentral': 6}
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.46
# The dataset contains 128 samples and 1656 features.
# The 23 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'WM_precentral': 2, 'superiorfrontal': 4, 'postcentral': 7, 'precentral': 6}
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.46
# The dataset contains 128 samples and 1728 features.
# The 24 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 1, 'WM_precentral': 2, 'superiorfrontal': 4, 'postcentral': 7, 'precentral': 6}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.51
# The dataset contains 128 samples and 1800 features.
# The 25 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 1, 'WM_precentral': 3, 'superiorfrontal': 4, 'postcentral': 7, 'precentral': 6}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.51
# The dataset contains 128 samples and 1872 features.
# The 26 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 1, 'WM_precentral': 3, 'superiorfrontal': 5, 'postcentral': 7, 'precentral': 6}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.49
# The dataset contains 128 samples and 1944 features.
# The 27 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 1, 'WM_precentral': 3, 'superiorfrontal': 5, 'postcentral': 7, 'precentral': 7}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.54
# The dataset contains 128 samples and 2016 features.
# The 28 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 1, 'WM_precentral': 3, 'superiorfrontal': 5, 'postcentral': 7, 'precentral': 8}
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.56
# The dataset contains 128 samples and 2088 features.
# The 29 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 2, 'WM_precentral': 3, 'superiorfrontal': 5, 'postcentral': 7, 'precentral': 8}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.56
# The dataset contains 128 samples and 2160 features.
# The 30 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 2, 'WM_precentral': 3, 'superiorfrontal': 5, 'postcentral': 7, 'precentral': 9}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.49
# The dataset contains 128 samples and 2232 features.
# The 31 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 2, 'WM_precentral': 4, 'superiorfrontal': 5, 'postcentral': 7, 'precentral': 9}
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.54
# The dataset contains 128 samples and 2304 features.
# The 32 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 3, 'WM_precentral': 4, 'superiorfrontal': 5, 'postcentral': 7, 'precentral': 9}
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.59
# The dataset contains 128 samples and 2376 features.
# The 33 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 3, 'WM_precentral': 4, 'superiorfrontal': 5, 'postcentral': 8, 'precentral': 9}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.64
# SVM PCA Accuracy: 0.41
# RF Accuracy: 0.59
# The dataset contains 128 samples and 2448 features.
# The 34 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 4, 'insula': 3, 'WM_precentral': 4, 'superiorfrontal': 5, 'postcentral': 8, 'precentral': 10}
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.64
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.44
# The dataset contains 128 samples and 2520 features.
# The 35 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 5, 'insula': 3, 'WM_precentral': 4, 'superiorfrontal': 5, 'postcentral': 8, 'precentral': 10}
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.41
# The dataset contains 128 samples and 2592 features.
# The 36 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 5, 'insula': 3, 'WM_precentral': 5, 'superiorfrontal': 5, 'postcentral': 8, 'precentral': 10}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.59
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.51
# The dataset contains 128 samples and 2664 features.
# The 37 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 5, 'insula': 3, 'WM_precentral': 5, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 10}
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.51
# The dataset contains 128 samples and 2736 features.
# The 38 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 6, 'insula': 3, 'WM_precentral': 5, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 10}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.56
# SVM Accuracy: 0.62
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.54
# The dataset contains 128 samples and 2808 features.
# The 39 most relevant channels are located in the following locations:
# {'caudalmiddlefrontal': 6, 'insula': 3, 'WM_precentral': 5, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 11}
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.62
# RF Accuracy: 0.51
# The dataset contains 128 samples and 2880 features.
# The 40 most relevant channels are located in the following locations:
# {'paracentral': 1, 'caudalmiddlefrontal': 6, 'insula': 3, 'WM_precentral': 5, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 11}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.59
# SVM Accuracy: 0.59
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.46
# The dataset contains 128 samples and 2952 features.
# The 41 most relevant channels are located in the following locations:
# {'paracentral': 1, 'caudalmiddlefrontal': 7, 'insula': 3, 'WM_precentral': 5, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 11}
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.54
# The dataset contains 128 samples and 3024 features.
# The 42 most relevant channels are located in the following locations:
# {'paracentral': 1, 'caudalmiddlefrontal': 7, 'insula': 3, 'WM_precentral': 5, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 12}
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.64
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.56
# The dataset contains 128 samples and 3096 features.
# The 43 most relevant channels are located in the following locations:
# {'paracentral': 1, 'caudalmiddlefrontal': 7, 'insula': 3, 'WM_precentral': 5, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 13}
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.49
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.62
# The dataset contains 128 samples and 3168 features.
# The 44 most relevant channels are located in the following locations:
# {'paracentral': 1, 'caudalmiddlefrontal': 7, 'insula': 3, 'WM_precentral': 6, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 13}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.46
# The dataset contains 128 samples and 3240 features.
# The 45 most relevant channels are located in the following locations:
# {'paracentral': 1, 'caudalmiddlefrontal': 7, 'insula': 3, 'WM_precentral': 6, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 14}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.56
# SVM Accuracy: 0.64
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.56
# The dataset contains 128 samples and 3312 features.
# The 46 most relevant channels are located in the following locations:
# {'paracentral': 2, 'caudalmiddlefrontal': 7, 'insula': 3, 'WM_precentral': 6, 'superiorfrontal': 6, 'postcentral': 8, 'precentral': 14}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.56
# SVM Accuracy: 0.64
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.56
# The dataset contains 128 samples and 3384 features.
# The 47 most relevant channels are located in the following locations:
# {'paracentral': 2, 'caudalmiddlefrontal': 7, 'insula': 3, 'WM_precentral': 6, 'superiorfrontal': 7, 'postcentral': 8, 'precentral': 14}
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.59
# The dataset contains 128 samples and 3456 features.
# The 48 most relevant channels are located in the following locations:
# {'paracentral': 2, 'caudalmiddlefrontal': 7, 'insula': 3, 'WM_precentral': 6, 'superiorfrontal': 7, 'postcentral': 9, 'precentral': 14}
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.56
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.56
# The dataset contains 128 samples and 3528 features.
# The 49 most relevant channels are located in the following locations:
# {'paracentral': 2, 'caudalmiddlefrontal': 7, 'insula': 3, 'WM_precentral': 6, 'superiorfrontal': 7, 'postcentral': 9, 'precentral': 15}
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.56
# The dataset contains 128 samples and 3600 features.
# The 50 most relevant channels are located in the following locations:
# {'paracentral': 2, 'caudalmiddlefrontal': 7, 'insula': 4, 'WM_precentral': 6, 'superiorfrontal': 7, 'postcentral': 9, 'precentral': 15}
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.49
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.56
# The dataset contains 128 samples and 3672 features.
# The 51 most relevant channels are located in the following locations:
# {'paracentral': 2, 'caudalmiddlefrontal': 7, 'insula': 5, 'WM_precentral': 6, 'superiorfrontal': 7, 'postcentral': 9, 'precentral': 15}
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.54

# %%
plt.plot(logreg_accuracies, '--', alpha=0.7, label='Logistic Regression')
plt.plot(logreg_pca_accuracies, '--', alpha=0.7, label='Logistic Regression PCA')
plt.plot(svm_accuracies, '--', alpha=0.7, label='SVM')
plt.plot(svm_pca_accuracies, '--', alpha=0.7, label='SVM PCA')
plt.plot(rf_accuracies, '--', alpha=0.7, label='Random Forest')
plt.legend()
plt.xlabel('Number of most relevant channels')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. number of most relevant channels')
plt.show()
