# %% [markdown]
# # MNE

# %%
import mne
import os 
import matplotlib.pyplot as plt
from constants import FIF_PATH

# %%
# Loading fif file with MNE
participant = 's6'
path = os.path.join(os.getcwd(), '..', 'Data', f'Dataset_subjects_{participant}_Exe_Obs.fif')
epochs = mne.read_epochs(path, preload=True)
# Out:
# Reading c:\Users\sarah\OneDrive\NXMA1\ML\ml-project-2-ml4science_tne\Code\..\Data\Dataset_subjects_s6_Exe_Obs.fif ...
# C:\Users\sarah\AppData\Local\Temp\ipykernel_19252\2932281701.py:4: RuntimeWarning: This filename (c:\Users\sarah\OneDrive\NXMA1\ML\ml-project-2-ml4science_tne\Code\..\Data\Dataset_subjects_s6_Exe_Obs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path, preload=True)
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    6999.51 ms
#         0 CTF compensation matrices available
# Adding metadata with 3 columns
# 256 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
plt.rcParams['agg.path.chunksize'] = 1000
epochs.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
epochs.plot(duration=5, n_channels=30)
plt.isoff()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 epochs.plot(duration=5, n_channels=30)
#       2 plt.isoff()
#
# TypeError: BaseEpochs.plot() got an unexpected keyword argument 'duration'
