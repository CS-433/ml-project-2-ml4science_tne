# %%
from utils import *
from dataset import *
from constants import *
from models.BaseModels import *

from itertools import chain, combinations

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from dataset import Participant

# Reproducibility
seed_num = RANDOM_STATE # This seed will be used for all random number generators
random.seed(seed_num) # Python's random will use seed_num
np.random.seed(seed_num) # NumPy's random number generator will use seed_num

# %%
use_saved = True
part_name = 's6'

# %%
if use_saved:
    participant = Participant.load_from_pickle(f'saved/{part_name}.pkl')
else:
    participant = Participant(part_name, data_path=DATA_PATH_NOTEBOOK, alpha=ALPHA)
    saved_dir = os.path.join(os.getcwd(), 'saved')
    if not os.path.exists(saved_dir):
        os.makedirs(saved_dir)
    with open(f'saved/{part_name}.pkl', 'wb', create_parents=True) as f:
        pickle.dump(participant, f, pickle.HIGHEST_PROTOCOL)

# %%
test_size = 0.3
pca_expl_var = 0.95

# %% [markdown]
# ## Observation

# %%
obs_features_dict = {}

for freq_name, freq_band in FREQ_BANDS.items():
    obs_features_dict[freq_name] = participant.get_features_all_sessions_mvt('O', freq_band={freq_name: freq_band})
# Out:
# 100%|██████████| 256/256 [02:01<00:00,  2.10it/s]
# 100%|██████████| 256/256 [01:24<00:00,  3.02it/s]
# 100%|██████████| 256/256 [01:10<00:00,  3.65it/s]
# 100%|██████████| 256/256 [01:03<00:00,  4.05it/s]
# 100%|██████████| 256/256 [01:01<00:00,  4.16it/s]
# 100%|██████████| 256/256 [01:03<00:00,  4.04it/s]

# %%
freq_list = list(FREQ_BANDS.keys())
freq_powerset = list(chain.from_iterable(combinations(freq_list, r) for r in range(1, len(freq_list) + 1)))

# %%
logreg_accuracies = []
logreg_pca_accuracies = []
svm_accuracies = []
svm_pca_accuracies = []
rf_accuracies = []

y = obs_features_dict['Alpha']['label']
for subfreqs in freq_powerset:
    features = [obs_features_dict[freq_name].drop('label', axis=1) for freq_name in subfreqs]
    obs_features = pd.concat(features, axis=1)
    print(f'Using only frequencies in the band(s) {subfreqs}...')
    print(f'The dataset contains {obs_features.shape[0]} samples and {obs_features.shape[1]} features.')

    X_train, X_test, y_train, y_test = train_test_split(obs_features, y, test_size=test_size, random_state=RANDOM_STATE)
    logreg = LogisticRegressionModel()
    logreg.fit(X_train, y_train)
    y_pred = logreg.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    logreg_accuracies.append(accuracy)
    print(f"LogReg Accuracy: {accuracy:.2f}")
    logreg = LogisticRegressionModel(use_pca=True, expl_var=pca_expl_var)
    logreg.fit(X_train, y_train)
    y_pred = logreg.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    logreg_pca_accuracies.append(accuracy)
    print(f"LogReg PCA Accuracy: {accuracy:.2f}")
    svm = SVMModel()
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    svm_accuracies.append(accuracy)
    print(f"SVM Accuracy: {accuracy:.2f}")
    svm = SVMModel(use_pca=True, expl_var=pca_expl_var)
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    svm_pca_accuracies.append(accuracy)
    print(f"SVM PCA Accuracy: {accuracy:.2f}")
    svm = RandomForestModel()
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    rf_accuracies.append(accuracy)
    print(f"RF Accuracy: {accuracy:.2f}")
# Out:
# Using only frequencies in the band(s) ('Delta',)...
# The dataset contains 128 samples and 612 features.
# LogReg Accuracy: 0.46
# LogReg PCA Accuracy: 0.56
# SVM Accuracy: 0.41
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.44
# Using only frequencies in the band(s) ('Theta',)...
# The dataset contains 128 samples and 612 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.56
# SVM Accuracy: 0.44
# SVM PCA Accuracy: 0.38
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Alpha',)...
# The dataset contains 128 samples and 612 features.
# LogReg Accuracy: 0.38
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.41
# RF Accuracy: 0.38
# Using only frequencies in the band(s) ('Beta',)...
# The dataset contains 128 samples and 612 features.
# LogReg Accuracy: 0.46
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.38
# RF Accuracy: 0.36
# Using only frequencies in the band(s) ('Gamma',)...
# The dataset contains 128 samples and 612 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.49
# SVM PCA Accuracy: 0.44
# RF Accuracy: 0.49
# Using only frequencies in the band(s) ('HighGamma',)...
# The dataset contains 128 samples and 612 features.
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.59
# SVM PCA Accuracy: 0.62
# RF Accuracy: 0.62
# Using only frequencies in the band(s) ('Delta', 'Theta')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.44
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.51
# Using only frequencies in the band(s) ('Delta', 'Alpha')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.44
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.49
# Using only frequencies in the band(s) ('Delta', 'Beta')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.41
# LogReg PCA Accuracy: 0.36
# SVM Accuracy: 0.38
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.36
# Using only frequencies in the band(s) ('Delta', 'Gamma')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.41
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.44
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.46
# Using only frequencies in the band(s) ('Delta', 'HighGamma')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.64
# SVM Accuracy: 0.64
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.56
# Using only frequencies in the band(s) ('Theta', 'Alpha')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.36
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.49
# Using only frequencies in the band(s) ('Theta', 'Beta')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.41
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Theta', 'Gamma')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.41
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Theta', 'HighGamma')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.64
# SVM Accuracy: 0.62
# SVM PCA Accuracy: 0.67
# RF Accuracy: 0.56
# Using only frequencies in the band(s) ('Alpha', 'Beta')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.31
# LogReg PCA Accuracy: 0.38
# SVM Accuracy: 0.28
# SVM PCA Accuracy: 0.44
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Alpha', 'Gamma')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.44
# SVM PCA Accuracy: 0.41
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Alpha', 'HighGamma')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.62
# Using only frequencies in the band(s) ('Beta', 'Gamma')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.44
# SVM PCA Accuracy: 0.38
# RF Accuracy: 0.36
# Using only frequencies in the band(s) ('Beta', 'HighGamma')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.64
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.62
# Using only frequencies in the band(s) ('Gamma', 'HighGamma')...
# The dataset contains 128 samples and 1224 features.
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.62
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.62
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Alpha')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.49
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.46
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Beta')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.36
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.49
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Gamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.33
# SVM Accuracy: 0.41
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.44
# Using only frequencies in the band(s) ('Delta', 'Theta', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.59
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.59
# Using only frequencies in the band(s) ('Delta', 'Alpha', 'Beta')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.41
# LogReg PCA Accuracy: 0.38
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Delta', 'Alpha', 'Gamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.46
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.41
# SVM PCA Accuracy: 0.44
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Delta', 'Alpha', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.44
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.62
# RF Accuracy: 0.59
# Using only frequencies in the band(s) ('Delta', 'Beta', 'Gamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.44
# LogReg PCA Accuracy: 0.33
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.44
# Using only frequencies in the band(s) ('Delta', 'Beta', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.46
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.67
# RF Accuracy: 0.62
# Using only frequencies in the band(s) ('Delta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.64
# Using only frequencies in the band(s) ('Theta', 'Alpha', 'Beta')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.41
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Theta', 'Alpha', 'Gamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.44
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Theta', 'Alpha', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.67
# SVM PCA Accuracy: 0.67
# RF Accuracy: 0.67
# Using only frequencies in the band(s) ('Theta', 'Beta', 'Gamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.31
# Using only frequencies in the band(s) ('Theta', 'Beta', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.59
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.62
# Using only frequencies in the band(s) ('Theta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.64
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.59
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.62
# Using only frequencies in the band(s) ('Alpha', 'Beta', 'Gamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.31
# Using only frequencies in the band(s) ('Alpha', 'Beta', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.54
# Using only frequencies in the band(s) ('Alpha', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.62
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.56
# Using only frequencies in the band(s) ('Beta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 1836 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.56
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Alpha', 'Beta')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.38
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Alpha', 'Gamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.38
# SVM Accuracy: 0.41
# SVM PCA Accuracy: 0.54
# RF Accuracy: 0.44
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Alpha', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.46
# LogReg PCA Accuracy: 0.59
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.62
# RF Accuracy: 0.56
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Beta', 'Gamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.38
# SVM PCA Accuracy: 0.44
# RF Accuracy: 0.38
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Beta', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.62
# RF Accuracy: 0.56
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.62
# SVM PCA Accuracy: 0.64
# RF Accuracy: 0.49
# Using only frequencies in the band(s) ('Delta', 'Alpha', 'Beta', 'Gamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.41
# LogReg PCA Accuracy: 0.41
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.41
# Using only frequencies in the band(s) ('Delta', 'Alpha', 'Beta', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.54
# Using only frequencies in the band(s) ('Delta', 'Alpha', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.49
# RF Accuracy: 0.59
# Using only frequencies in the band(s) ('Delta', 'Beta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.49
# LogReg PCA Accuracy: 0.56
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.46
# Using only frequencies in the band(s) ('Theta', 'Alpha', 'Beta', 'Gamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.44
# RF Accuracy: 0.38
# Using only frequencies in the band(s) ('Theta', 'Alpha', 'Beta', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.67
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.59
# Using only frequencies in the band(s) ('Theta', 'Alpha', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.62
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.54
# Using only frequencies in the band(s) ('Theta', 'Beta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.56
# SVM PCA Accuracy: 0.59
# RF Accuracy: 0.49
# Using only frequencies in the band(s) ('Alpha', 'Beta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 2448 features.
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.54
# SVM Accuracy: 0.46
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.46
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Alpha', 'Beta', 'Gamma')...
# The dataset contains 128 samples and 3060 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.44
# SVM PCA Accuracy: 0.38
# RF Accuracy: 0.44
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Alpha', 'Beta', 'HighGamma')...
# The dataset contains 128 samples and 3060 features.
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.46
# SVM Accuracy: 0.59
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.56
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Alpha', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 3060 features.
# LogReg Accuracy: 0.59
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.59
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.64
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Beta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 3060 features.
# LogReg Accuracy: 0.56
# LogReg PCA Accuracy: 0.49
# SVM Accuracy: 0.54
# SVM PCA Accuracy: 0.46
# RF Accuracy: 0.56
# Using only frequencies in the band(s) ('Delta', 'Alpha', 'Beta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 3060 features.
# LogReg Accuracy: 0.54
# LogReg PCA Accuracy: 0.44
# SVM Accuracy: 0.49
# SVM PCA Accuracy: 0.51
# RF Accuracy: 0.51
# Using only frequencies in the band(s) ('Theta', 'Alpha', 'Beta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 3060 features.
# LogReg Accuracy: 0.51
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.44
# RF Accuracy: 0.59
# Using only frequencies in the band(s) ('Delta', 'Theta', 'Alpha', 'Beta', 'Gamma', 'HighGamma')...
# The dataset contains 128 samples and 3672 features.
# LogReg Accuracy: 0.62
# LogReg PCA Accuracy: 0.51
# SVM Accuracy: 0.51
# SVM PCA Accuracy: 0.56
# RF Accuracy: 0.56

# %%
width = 0.15
ind = np.arange(len(freq_powerset))

plt.figure(figsize=(10,5))
plt.bar(ind, logreg_accuracies, width, label='Logistic Regression')
plt.bar(ind + width, logreg_pca_accuracies, width, label='Logistic Regression PCA')
plt.bar(ind + 2*width, svm_accuracies, width, label='SVM')
plt.bar(ind + 3*width, svm_accuracies, width, label='SVM PCA')
plt.bar(ind + 4*width, rf_accuracies, width, label='Random Forest')
plt.xticks(ind + 2*width, freq_powerset, rotation=90)
plt.axhline(0.5, linestyle='--', color='k')
plt.legend()
plt.ylabel('Accuracy')
plt.title('Accuracy by frequency band (observation)')
plt.show()

# %%
# General
plt.rcParams["font.family"] = "Times New Roman"
SMALL_SIZE = 20
MEDIUM_SIZE = 22
BIGGER_SIZE = 28

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE, titleweight = 'bold', titlepad = 20)    # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE, labelweight = 'bold', labelpad = 15)   # fontsize of the x and y labels    
plt.rc('xtick', labelsize=SMALL_SIZE, direction = 'out')    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE, direction = 'out')    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('axes.spines', top=False, right=False)  # Removing the top and right spines  

width = 0.15
ind = np.arange(len(freq_powerset))

plt.figure(figsize=(10,5))
plt.bar(ind[:6], logreg_accuracies[:6], width, label='Logistic Regression')
plt.bar(ind[:6] + width, logreg_pca_accuracies[:6], width, label='Logistic Regression PCA')
plt.bar(ind[:6] + 2*width, svm_accuracies[:6], width, label='SVM')
plt.bar(ind[:6] + 3*width, svm_accuracies[:6], width, label='SVM PCA')
plt.bar(ind[:6] + 4*width, rf_accuracies[:6], width, label='Random Forest')
plt.xticks(ind[:6] + 2*width, ['Delta', 'Theta', 'Alpha', 'Beta', 'Gamma', 'High Gamma'])
plt.axhline(0.5, linestyle='--', color='k', legend='Chance level')
plt.legend(loc='lower right', fontsize=10)
plt.ylabel('Accuracy')
plt.title('Accuracy by frequency band (execution)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 26
#      24 plt.bar(ind[:6] + 4*width, rf_accuracies[:6], width, label='Random Forest')
#      25 plt.xticks(ind[:6] + 2*width, ['Delta', 'Theta', 'Alpha', 'Beta', 'Gamma', 'High Gamma'])
# ---> 26 plt.axhline(0.5, linestyle='--', color='k', legend='Chance level')
#      27 plt.legend(loc='lower right', fontsize=10)
#      28 plt.ylabel('Accuracy')
#
# File c:\Users\sarah\miniconda3\envs\TNE\Lib\site-packages\matplotlib\pyplot.py:2895, in axhline(y, xmin, xmax, **kwargs)
#    2893 @_copy_docstring_and_deprecators(Axes.axhline)
#    2894 def axhline(y: float = 0, xmin: float = 0, xmax: float = 1, **kwargs) -> Line2D:
# -> 2895     return gca().axhline(y=y, xmin=xmin, xmax=xmax, **kwargs)
#
# File c:\Users\sarah\miniconda3\envs\TNE\Lib\site-packages\matplotlib\axes\_axes.py:827, in Axes.axhline(self, y, xmin, xmax, **kwargs)
#     824 scaley = (yy < ymin) or (yy > ymax)
#     826 trans = self.get_yaxis_transform(which='grid')
# --> 827 l = mlines.Line2D([xmin, xmax], [y, y], transform=trans, **kwargs)
#     828 self.add_line(l)
#     829 l.get_path()._interpolation_steps = mpl.axis.GRIDLINE_INTERPOLATION_STEPS
#
# File c:\Users\sarah\miniconda3\envs\TNE\Lib\site-packages\matplotlib\lines.py:407, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     403 self.set_markeredgewidth(markeredgewidth)
#     405 # update kwargs before updating data to give the caller a
#     406 # chance to init axes (and hence unit support)
# --> 407 self._internal_update(kwargs)
#     408 self.pickradius = pickradius
#     409 self.ind_offset = 0
#
# File c:\Users\sarah\miniconda3\envs\TNE\Lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File c:\Users\sarah\miniconda3\envs\TNE\Lib\site-packages\matplotlib\artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'legend'
