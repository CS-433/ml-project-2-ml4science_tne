# %%
from dataset import *

# %%
s6 = participant('s6', data_path='../Data/Dataset_4subjects_Exe_Obs')

# %%
dataset = s6.get_features_all_sessions()

# %%
dataset
# Out:
#     label  CH0_Delta_mean_window_0  CH0_Delta_mean_window_1  \
# 0       O                 6.365135                 6.278756
# 1       O                 5.457896                 5.484021
# 2       O                 6.433025                 6.553713
# 3       E                21.662774                21.713520
# 4       O                 7.145099                 7.636449
# ..    ...                      ...                      ...
# 251     O                10.269263                10.170379
# 252     E                 6.433373                 6.933454
# 253     O                15.469338                15.439392
# 254     O                 8.761411                 8.468760
# 255     E                30.576239                31.150031
#
#      CH0_Delta_mean_window_2  CH0_Delta_mean_window_3  \
# 0                   6.314461                 6.370334
# 1                   5.629392                 5.799791
# 2                   6.778325                 7.015785
# ...
